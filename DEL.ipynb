# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjavMehta01/Truist-Credit_Risk_SAS/blob/Nishang/DEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdate
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
de = pd.read_csv('/content/drive/My Drive/summer project/Copy of train_DEL.csv')
#de['Act_date']= pd.to_datetime(de['Act_date'],format= '%m/%d/%y') 
de
# Out:
#             Loan_id  Orig_amt  Orig_dte  Oltv  ...  UMP    PPI      HPI    yqtr
# 0      100193915350    119000  04/01/09    71  ...  5.3  194.8  171.467  2015Q2
# 1      100193915350    119000  04/01/09    71  ...  5.0  189.1  173.847  2015Q3
# 2      100193915350    119000  04/01/09    71  ...  5.0  183.5  176.598  2015Q4
# 3      100413254871     90000  11/01/08    67  ...  9.4  186.6  142.526  2010Q4
# 4      100413254871     90000  11/01/08    67  ...  9.1  203.1  140.006  2011Q2
# ...             ...       ...       ...   ...  ...  ...    ...      ...     ...
# 11756  998908346394    133000  02/01/06    89  ...  4.7  173.5  177.567  2007Q3
# 11757  999238630268    166000  10/01/08    95  ...  9.9  178.1  147.935  2009Q4
# 11758  999557110284     75000  04/01/11    41  ...  7.5  204.3  154.202  2013Q2
# 11759  999955193848    264000  04/01/07    80  ...  9.9  178.1  147.935  2009Q4
# 11760  999975026036    100000  07/01/13    75  ...  5.9  206.4  165.915  2014Q3
#
# [11761 rows x 22 columns]

# %%
def flag(state):
  if state == 'PPY':
    return '-1'
  elif state == 'CUR':
    return '0'
  elif state == 'DEL':
    return '1'
  else:
    return '2'

de['flag'] = de['Next_stat'].map(flag)

de.head()
# Out:
#         Loan_id  Orig_amt  Orig_dte  Oltv  ...    PPI      HPI    yqtr flag
# 0  100193915350    119000  04/01/09    71  ...  194.8  171.467  2015Q2    1
# 1  100193915350    119000  04/01/09    71  ...  189.1  173.847  2015Q3    1
# 2  100193915350    119000  04/01/09    71  ...  183.5  176.598  2015Q4    1
# 3  100413254871     90000  11/01/08    67  ...  186.6  142.526  2010Q4    0
# 4  100413254871     90000  11/01/08    67  ...  203.1  140.006  2011Q2    0
#
# [5 rows x 23 columns]

# %%
de = de.drop(['Loan_id','Orig_dte','Act_date','Next_stat','yqtr'],axis=1)

# %%
prime = de.loc[de['Cscore_b'] >= 670]
de = de.loc[de['Cscore_b'] < 670]

# %%
def dum(list, dataset):
  for col in list:
      x =pd.get_dummies(dataset[col] ,prefix = col)
      dataset = pd.concat([dataset,x], axis=1)
  return dataset
# plan a : using full Categorical
dumlist = ['Purpose', 'Prop_typ', 'Occ_stat','Fthb_flg','Num_unit']
de = dum(dumlist,de)

# %%
# plan b&c: only purpose kept
dumlist = ['Purpose']
de = dum(dumlist,de)
de = de.drop(['Prop_typ', 'Occ_stat','Fthb_flg','Num_unit'],axis=1)
de.head()
# Out:
#    Orig_amt  Oltv   Dti  Cscore_b  ... Num_unit_4  Purpose_C  Purpose_P  Purpose_R
# 0    119000    71  41.0       789  ...          0          0          0          1
# 1    119000    71  41.0       789  ...          0          0          0          1
# 2    119000    71  41.0       789  ...          0          0          0          1
# 3     90000    67  47.0       696  ...          0          0          0          1
# 4     90000    67  47.0       696  ...          0          0          0          1
#
# [5 rows x 34 columns]

# %%
sns.distplot(de['Cscore_b'])

# %%
#plan a: group FICO
labels = ["{0} - {1}".format(i, i + 49) for i in range(520, 785, 50)]
de['FICO_group'] = pd.cut(de['Cscore_b'], range(520, 835, 50), right=False, labels=labels)
de.head()
# Out:
#    Orig_amt  Oltv   Dti  Cscore_b  ... Purpose_C  Purpose_P  Purpose_R  FICO_group
# 0    119000    71  41.0       789  ...         0          0          1   770 - 819
# 1    119000    71  41.0       789  ...         0          0          1   770 - 819
# 2    119000    71  41.0       789  ...         0          0          1   770 - 819
# 3     90000    67  47.0       696  ...         0          0          1   670 - 719
# 4     90000    67  47.0       696  ...         0          0          1   670 - 719
#
# [5 rows x 35 columns]

# %%
sns.distplot(de['Orig_amt'])

# %%
#plan a: group Original UPB
labels = ["{0} - {1}".format(i, i + 99999) for i in range(0, 700001, 100000)]
de['UPB_group'] = pd.cut(de['Orig_amt'], range(0, 800001, 100000), right=False, labels=labels)
de.head()
# Out:
#    Orig_amt  Oltv   Dti  ...  Purpose_R FICO_group        UPB_group
# 0    119000    71  41.0  ...          1  770 - 819  100000 - 199999
# 1    119000    71  41.0  ...          1  770 - 819  100000 - 199999
# 2    119000    71  41.0  ...          1  770 - 819  100000 - 199999
# 3     90000    67  47.0  ...          1  670 - 719        0 - 99999
# 4     90000    67  47.0  ...          1  670 - 719        0 - 99999
#
# [5 rows x 36 columns]

# %%
# B 
dumlist1 = ['UPB_group']
de = dum(dumlist1,de)
de.head()

# %%
# A
dumlist1 = ['FICO_group', 'UPB_group']
de = dum(dumlist1,de)

# %%
de['ratio_upb'] = de['Act_upb']/de['Orig_amt']

# %%
#A
de = de.drop(dumlist,axis=1)
de = de.drop(dumlist1, axis=1)
de = de.drop(['Cscore_b','Orig_amt','Act_upb'],axis=1)
de.head()

# %%
de.head()
# Out:
#    Orig_amt  Oltv   Dti  ...  Num_unit_3 Num_unit_4 ratio_upb
# 0    119000    71  41.0  ...           0          0  0.890640
# 1    119000    71  41.0  ...           0          0  0.885439
# 2    119000    71  41.0  ...           0          0  0.881940
# 3     90000    67  47.0  ...           0          0  0.973454
# 4     90000    67  47.0  ...           0          0  0.967016
#
# [5 rows x 36 columns]

# %%
#A
#standardlized some of the Macro(equal scale & converge problem)

def stdmac(maclist, dataset):
  sampledes = dataset.describe()
  for mac in maclist:
    dataset[mac] = dataset[mac].map(lambda x: (x - sampledes[mac]['mean'])/sampledes[mac]['std'])
  return dataset

macrolist=['GDP','HS','PPI','HPI']
de = stdmac(macrolist, de)

# %%
macrolist=['Orig_amt']
de = stdmac(macrolist, de)
de.head()
# Out:
#    Orig_amt  Oltv   Dti  ...  Num_unit_3 Num_unit_4 ratio_upb
# 0 -0.766057    71  41.0  ...           0          0  0.890640
# 1 -0.766057    71  41.0  ...           0          0  0.885439
# 2 -0.766057    71  41.0  ...           0          0  0.881940
# 3 -1.040826    67  47.0  ...           0          0  0.973454
# 4 -1.040826    67  47.0  ...           0          0  0.967016
#
# [5 rows x 36 columns]

# %%
de = de.drop(dumlist, axis=1)
de.head()
# Out:
#    Orig_amt  Oltv   Dti  ...  Num_unit_3  Num_unit_4  ratio_upb
# 0 -0.766057    71  41.0  ...           0           0   0.890640
# 1 -0.766057    71  41.0  ...           0           0   0.885439
# 2 -0.766057    71  41.0  ...           0           0   0.881940
# 3 -1.040826    67  47.0  ...           0           0   0.973454
# 4 -1.040826    67  47.0  ...           0           0   0.967016
#
# [5 rows x 31 columns]

# %%
##C
#Logistic Regression simple
sampleNext = de.dropna()
dy = sampleNext['flag']
dx = sampleNext[['Orig_amt','Oltv','Dti','Cscore_b','Curr_rte', 'Loan_age','GDP','HS','UMP','PPI','HPI','Purpose_C','Purpose_P','Purpose_R','ratio_upb']]
import statsmodels.api as st
mdl = st.MNLogit(dy, dx)
mdl_fit = mdl.fit()
print (mdl_fit.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.973797
#          Iterations 7
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                   flag   No. Observations:                11552
# Model:                        MNLogit   Df Residuals:                    11507
# Method:                           MLE   Df Model:                           42
# Date:                Sun, 28 Jun 2020   Pseudo R-squ.:                 0.04323
# Time:                        04:46:05   Log-Likelihood:                -11249.
# converged:                       True   LL-Null:                       -11758.
# Covariance Type:            nonrobust   LLR p-value:                9.989e-186
# ==============================================================================
#     flag=0       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Orig_amt      -0.1123      0.051     -2.207      0.027      -0.212      -0.013
# Oltv           0.0043      0.004      1.174      0.240      -0.003       0.011
# Dti           -0.0039      0.006     -0.708      0.479      -0.015       0.007
# Cscore_b      -0.0035      0.001     -3.265      0.001      -0.006      -0.001
# Curr_rte      -0.3787      0.089     -4.274      0.000      -0.552      -0.205
# Loan_age       0.0124      0.003      3.682      0.000       0.006       0.019
# GDP           -0.6285      0.232     -2.708      0.007      -1.083      -0.174
# HS             0.1381      0.166      0.832      0.405      -0.187       0.463
# UMP            0.1243      0.113      1.102      0.271      -0.097       0.346
# PPI            0.0328      0.078      0.419      0.675      -0.120       0.186
# HPI            0.3720      0.227      1.641      0.101      -0.072       0.816
# Purpose_C      3.3877      1.265      2.679      0.007       0.909       5.867
# Purpose_P      3.5055      1.286      2.727      0.006       0.986       6.025
# Purpose_R      3.4247      1.270      2.697      0.007       0.936       5.914
# ratio_upb      2.3879      0.478      4.998      0.000       1.451       3.324
# ------------------------------------------------------------------------------
#     flag=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Orig_amt      -0.1588      0.052     -3.065      0.002      -0.260      -0.057
# Oltv           0.0153      0.004      4.091      0.000       0.008       0.023
# Dti            0.0099      0.006      1.770      0.077      -0.001       0.021
# Cscore_b      -0.0087      0.001     -7.979      0.000      -0.011      -0.007
# Curr_rte      -0.2610      0.089     -2.922      0.003      -0.436      -0.086
# Loan_age       0.0196      0.003      5.772      0.000       0.013       0.026
# GDP           -0.5857      0.234     -2.507      0.012      -1.044      -0.128
# HS             0.0014      0.167      0.008      0.993      -0.326       0.329
# UMP            0.1555      0.113      1.372      0.170      -0.067       0.378
# PPI            0.0392      0.079      0.497      0.619      -0.115       0.194
# HPI            0.5277      0.229      2.308      0.021       0.080       0.976
# Purpose_C      3.5122      1.281      2.741      0.006       1.001       6.023
# Purpose_P      3.3880      1.302      2.602      0.009       0.836       5.940
# Purpose_R      3.3769      1.286      2.625      0.009       0.856       5.898
# ratio_upb      3.5808      0.508      7.048      0.000       2.585       4.577
# ------------------------------------------------------------------------------
#     flag=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Orig_amt      -0.0322      0.062     -0.521      0.603      -0.153       0.089
# Oltv           0.0252      0.005      5.314      0.000       0.016       0.035
# Dti            0.0142      0.007      2.172      0.030       0.001       0.027
# Cscore_b      -0.0022      0.001     -1.709      0.087      -0.005       0.000
# Curr_rte      -0.1161      0.105     -1.100      0.271      -0.323       0.091
# Loan_age       0.0172      0.004      4.106      0.000       0.009       0.025
# GDP           -0.6438      0.276     -2.333      0.020      -1.185      -0.103
# HS            -0.3506      0.196     -1.792      0.073      -0.734       0.033
# UMP            0.0613      0.126      0.485      0.628      -0.186       0.309
# PPI           -0.0695      0.094     -0.740      0.459      -0.253       0.115
# HPI            0.3264      0.273      1.195      0.232      -0.209       0.862
# Purpose_C     -2.9972      1.558     -1.923      0.054      -6.052       0.057
# Purpose_P     -3.2414      1.583     -2.047      0.041      -6.345      -0.138
# Purpose_R     -3.2123      1.564     -2.053      0.040      -6.278      -0.146
# ratio_upb      2.5724      0.781      3.294      0.001       1.042       4.103
# ==============================================================================

# %%
##B
#Logistic Regression simple
sampleNext = de.dropna()
dy = sampleNext['flag']
dx = sampleNext.loc[:, sampleNext.columns != 'flag']
import statsmodels.api as st
mdl = st.MNLogit(dy, dx)
mdl_fit = mdl.fit()
print (mdl_fit.summary())

# %%
##C-2
#Logistic Regression simple
sampleNext = de.dropna()
dy = sampleNext['flag']
dx = sampleNext[['Oltv','Dti', 'Loan_age','GDP','Purpose_C','Purpose_P','Purpose_R','ratio_upb']]
import statsmodels.api as st
mdl = st.MNLogit(dy, dx)
mdl_fit = mdl.fit()
print (mdl_fit.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.989628
#          Iterations 7
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                   flag   No. Observations:                11552
# Model:                        MNLogit   Df Residuals:                    11528
# Method:                           MLE   Df Model:                           21
# Date:                Sun, 28 Jun 2020   Pseudo R-squ.:                 0.02768
# Time:                        04:52:55   Log-Likelihood:                -11432.
# converged:                       True   LL-Null:                       -11758.
# Covariance Type:            nonrobust   LLR p-value:                3.138e-124
# ==============================================================================
#     flag=0       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Oltv           0.0022      0.004      0.619      0.536      -0.005       0.009
# Dti           -0.0049      0.005     -0.899      0.369      -0.016       0.006
# Loan_age       0.0048      0.003      1.749      0.080      -0.001       0.010
# GDP           -0.0826      0.074     -1.118      0.264      -0.228       0.062
# Purpose_C      0.7521      0.514      1.462      0.144      -0.256       1.760
# Purpose_P      0.7962      0.542      1.470      0.142      -0.266       1.858
# Purpose_R      0.7891      0.517      1.527      0.127      -0.224       1.802
# ratio_upb      1.8629      0.467      3.985      0.000       0.947       2.779
# ------------------------------------------------------------------------------
#     flag=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Oltv           0.0131      0.004      3.556      0.000       0.006       0.020
# Dti            0.0105      0.006      1.902      0.057      -0.000       0.021
# Loan_age       0.0171      0.003      6.167      0.000       0.012       0.023
# GDP           -0.2737      0.075     -3.670      0.000      -0.420      -0.128
# Purpose_C     -2.5831      0.546     -4.730      0.000      -3.653      -1.513
# Purpose_P     -2.7975      0.574     -4.875      0.000      -3.922      -1.673
# Purpose_R     -2.7810      0.549     -5.069      0.000      -3.856      -1.706
# ratio_upb      3.4368      0.501      6.860      0.000       2.455       4.419
# ------------------------------------------------------------------------------
#     flag=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Oltv           0.0268      0.005      5.695      0.000       0.018       0.036
# Dti            0.0161      0.006      2.490      0.013       0.003       0.029
# Loan_age       0.0160      0.003      4.699      0.000       0.009       0.023
# GDP           -0.7565      0.092     -8.201      0.000      -0.937      -0.576
# Purpose_C     -4.7917      0.818     -5.858      0.000      -6.395      -3.188
# Purpose_P     -5.0997      0.849     -6.004      0.000      -6.764      -3.435
# Purpose_R     -5.0345      0.822     -6.125      0.000      -6.646      -3.423
# ratio_upb      2.4763      0.777      3.186      0.001       0.953       4.000
# ==============================================================================
